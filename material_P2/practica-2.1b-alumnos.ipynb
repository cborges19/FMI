# %%
import numpy as np

import practica-2.1a-alumnos.ipynb as he

# %%
# Cargar los datos VariableX.mat y VariableX_Y.mat

import scipy.io

# 1. Cargar los archivos .mat
# Estos archivos contienen las realizaciones de nuestras variables X e Y
data_x = scipy.io.loadmat('VariableX.mat')
data_xy = scipy.io.loadmat('VariableX_Y.mat')

# %% [markdown]
# ## 1. Cálculo de entropía

# %%
muestras_x = data_x['X']

# Lo convierto en un vector simple para mi función de entropía
vector_x = muestras_x.flatten() 

# Ahora ya puedo calcular H(X)
resultado_h = entropy_estimation(vector_x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       4 vector_x = muestras_x.flatten()
#       6 # Ahora ya puedo calcular H(X)
# ----> 7 resultado_h = entropy_estimation(vector_x)
#
# NameError: name 'entropy_estimation' is not defined

# %% [markdown]
# ## 2. Cálculo de entropía conjunta

# %% [markdown]
# ## 3. Cálculo de entropía condicional

# %% [markdown]
# ## 4. Cálculo información mutua

# %% [markdown]
# ## 5. Capacidad canal
