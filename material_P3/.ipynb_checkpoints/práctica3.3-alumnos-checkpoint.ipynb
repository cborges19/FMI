# %%
import numpy as np
import cvxpy as cp
from sklearn.svm import SVC
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt

# %%
# Resolver SVM con CVXPY

def solve_svm_with_cvxpy(X, y, C=1.0):
    n_samples,n_features = X.shape
    w = cp.Variable(n_features)
    b = cp.Variable()
    xi = cp.Variable(n_samples)
    
    
    

    # Definir el problema
    objective = cp.Minimize(0.5*cp.norm1(w) +C*cp.sum(xi)) 
    constraints = [cp.multiply(y,X@w+b) >= 1 -xi,
                  xi>=0]
    prob = cp.Problem(objective, constraints)
    prob.solve()

    return w.value, b.value, xi.value


    ########## REVISAR ME DABA DIFERENTES COEFICEITNES QUE AL PROFESOR

# %%
# Resolver SVM con sklearn
def solve_svm_with_sklearn(X, y, C=1.0):
    
    
    
    
    return

# %%
# Generar datos sintéticos
X, y = make_classification(n_samples=50, n_features=2, n_classes=2, n_informative=2, n_redundant=0, random_state=1)
y = 2 * y - 1  # Convertir etiquetas a {-1, 1}

# %%
# Calcular solución con CVXPY
C = 0.5
w_cvx, b_cvx, xi_cvx = solve_svm_with_cvxpy(X, y, C)


# Calcular solución con sklearn
#w_sklearn, b_sklearn = solve_svm_with_sklearn(X, y, C)
w_cvx, b_cvx, xi_cvx
# Out:
# (array([-0.44282727,  1.73900719]),
#  array(0.289173),
#  array([1.03605902e-10, 5.19936112e-10, 1.59020437e-10, 1.33692757e+00,
#         9.25091702e-11, 8.63365714e-11, 8.73498175e-11, 8.63411618e-11,
#         1.05238823e-10, 8.95038150e-11, 4.88308456e-10, 8.69784257e-11,
#         8.64192577e-11, 1.39837561e+00, 8.87023127e-11, 2.43811872e-09,
#         8.78695479e-11, 8.80696582e-11, 1.00330164e-10, 1.20194836e-10,
#         8.80033713e-11, 8.65701949e-11, 1.06535018e+00, 1.13952170e+00,
#         9.16684427e-11, 2.78322013e-01, 8.81408814e-11, 9.34302724e-11,
#         8.70084048e-11, 1.07481469e-10, 1.03737617e-10, 8.90220058e-11,
#         8.87276298e-11, 9.63132122e-11, 8.67924890e-11, 7.27279910e-01,
#         8.80221045e-11, 8.59627481e-11, 1.24261482e-10, 9.95424091e-11,
#         8.99830986e-11, 1.24347363e-10, 8.55224193e-11, 8.61954706e-11,
#         8.66772027e-11, 1.10239799e-10, 3.87566823e-02, 9.91379484e-11,
#         8.63722232e-11, 8.85880564e-11]))

# %%
# Visualizar resultados
def plot_svm(X, y, w, b, title):
    plt.figure(figsize=(8, 6))
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap='bwr', alpha=0.7, edgecolor='k')
    x_line = np.linspace(X[:, 0].min(), X[:, 0].max(), 100)
    y_line = -(w[0] * x_line + b) / w[1]
    plt.plot(x_line, y_line, 'k-', label="Margen de decisión")
    plt.fill_between(x_line, y_line - 1/np.linalg.norm(w), y_line + 1/np.linalg.norm(w), color='gray', alpha=0.2, label="Margen")
    plt.title(title)
    plt.legend()
    plt.show()

# Visualización con CVXPY
plot_svm(X, y, w_cvx, b_cvx, title="SVM con CVXPY")

# Visualización con sklearn
#plot_svm(X, y, w_sklearn, b_sklearn, title="SVM con sklearn")

# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd

# Cargar el dataset
data = load_breast_cancer()
X = data.data
y = data.target
y = 2 * y - 1 

# Crear un DataFrame para exploración
df = pd.DataFrame(X, columns=data.feature_names)
df['target'] = y

# Mostrar primeras filas
print(df.head())

# %%
# Calcular solución con sklearn

# %%
# Calcular solución con CVXPY

# %%
# Analizar los coeficientes w para i)SVM con L1 ii) SVM con L2 y iii) SVM con sklearn.
